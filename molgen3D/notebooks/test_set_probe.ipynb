# %%
from molgen3D.evaluation.utils import correct_smiles, clean_confs, get_unique_smiles
from collections import Counter
import os
import cloudpickle
import json

base_path = "/mnt/sxtn2/chem/GEOM_data"

test_mols_path = os.path.join(base_path, "geom_processed/test_smiles_corrected.csv")
drugs_file_path = os.path.join(base_path, "rdkit_folder/summary_drugs.json")
destination_path = "molgen3D/../data/inference_set_corrected_smiles"

def load_pkl(file_path: str):
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File {file_path} does not exist.")
    with open(file_path, "rb") as f:
        return cloudpickle.load(f)

with open(drugs_file_path, "r") as f:
    drugs_summ = json.load(f)

with open(test_mols_path, 'r') as f:
    print(f.readline())
    test_mols = [(m.split(',')) for m in f.readlines()]
test_mols = [(m[0].strip(), int(m[1]), m[2].strip()) for m in test_mols]
# Out:
# smiles,n_conformers,corrected_smiles

# %%
m380_4e_gens = load_pkl("/auto/home/menuab/code/3DMolGen/gen_results/2025-09-18-21:11_m380_4e_top_p_sampling1_distinct_smi/generation_results.pickle")
nm380_4e_gens = load_pkl("/auto/home/menuab/code/3DMolGen/gen_results/2025-09-18-17:39_nm380_4e_top_p_sampling1_distinct_smi/generation_results.pickle")

# %%
processed_drugs_test = {}
test_set_smiles = []
conf_count, mol_count = 0, 0
# zero_confs_count, less_confs_count = 0, 0
for i in range(len(test_mols)):
    geom_smiles = test_mols[i][0]
    geom_smiles_corrected = test_mols[i][2]
    true_num_confs = test_mols[i][1]
    mol_dic = load_pkl(os.path.join(*[base_path, "rdkit_folder", drugs_summ[geom_smiles]['pickle_path']]))

    true_confs = [conf['rd_mol'] for conf in mol_dic['conformers']]
    true_confs = clean_confs(geom_smiles, true_confs)
    num_confs = len(true_confs)
    if num_confs != true_num_confs:
        print(f"{geom_smiles=} has {num_confs} conformers, expected {true_num_confs}")
        print('***')
        conf_count += 1
# Out:
# geom_smiles='CC(=NCCc1ccccc1)C1=C(O)CSC1=O' has 0 conformers, expected 39
# ***
# geom_smiles='CC(=NCc1ccccc1)C1=C(O)C(C)OC1=O' has 0 conformers, expected 11
# ***
# geom_smiles='CC(C)(C)c1cc[n+](-c2[nH]c(=O)sc2/C=N/NC([S-])=Nc2ccccc2)cc1' has 0 conformers, expected 15
# ***
# geom_smiles='CC(C)CSC1=NSC2=NC(=O)/C(=C\\c3coc4ccccc4c3=O)C(=N)N12' has 0 conformers, expected 9
# ***
# geom_smiles='CC1(C)CC(=O)C(C=NCCN2CCN(C(=S)Nc3ccc(F)cc3)CC2)=C(O)C1' has 37 conformers, expected 38
# ***
# geom_smiles='CC1=[N+](CC(=O)c2ccccc2)CCn2cccc21' has 0 conformers, expected 2
# ***
# geom_smiles='CCC(Cc1ccccc1)NS(=O)(=O)c1c(C)nc2scc(C)n2c1=O' has 0 conformers, expected 16
# ***
# geom_smiles='CCC(Sc1nc2n[nH]c(C)c2c(=N)n1-c1cccc(Cl)c1)C(=O)NCCOC' has 0 conformers, expected 219
# ***
# geom_smiles='CCC1=NN2C(=N)/C(=C/c3c(C)nn(-c4ccccc4)c3Cl)C(=O)N=C2S1' has 0 conformers, expected 11
# ***
C@H](C)[C@H](O)[C@@H](C)[C@@H](O)[C@@H](C)[C@H](OC(C)=O)[C@@H]1C', 'COc1cc(C(=O)Nc2nnc(C(F)(F)F)s2)c([N+](=O)[O-])cc1OC', 'COc1cc(/C=C2/C(=O)NN(c3cccc(C)c3)C2=O)cc([N+](=O)[O-])c1O', 'COc1ccc(-n2c(=O)c3c4c(sc3n3c(C)nnc23)CCCC4)cc1', 'COc1ccc(C(=O)CSc2nc(N)nc(SC)c2C#N)cc1', 'COc1ccc(NC(=O)CSc2nc(O)cc(=O)n2C)cc1', 'COc1ccc2oc(=N)c(C(=O)Nc3cccc(C)c3C)cc2c1', 'CS/C(N)=N/S(=O)(=O)c1ccc(NC(C)=O)cc1', 'CSc1nc2c(c(=O)[nH]1)C(c1ccc(Br)cc1)CC(=O)N2', 'CSc1ncccc1C(=O)OCC(=O)c1ccc(Br)s1', 'Cc1c(N=C2NC(=O)/C(=C/c3cccc([N+](=O)[O-])c3)S2)c(=O)n(-c2ccccc2)n1C', 'Cc1cc(-c2ccc(/C=N/n3cnnc3)o2)c([N+](=O)[O-])cc1C', 'Cc1cc(C(=O)Nc2c(F)cc(F)cc2Br)cs1', 'Cc1cc(C(C#N)c2ccc(Cl)cc2)c(Cl)cc1NC(=O)c1cc(I)cc(I)c1[O-]', 'Cc1cc(NC(=O)CSc2nc3c(c(=O)n2CCc2ccccc2)SC(C)C3)no1', 'Cc1cc(OCC[NH+]2CCOCC2)nc2ccccc12', 'Cc1ccc(CC2SC(N)=NC2=O)cc1', 'Cc1ccc(NC(=O)CSc2nccc(=O)[nH]2)c(S(=O)(=O)N2CCOCC2)c1', 'Cc1ccc(S(=O)(=O)c2cc3c(=O)n4ccccc4nc3n(C)c2=N)cc1C', 'Cc1ccc(/C=C2\\SC(N3CCN(C(c4ccccc4)c4ccccc4)CC3)=NC2=O)o1', 'Cc1ccc2[nH]c(O)c(N=Nc3nc4ccccc4s3)c2c1', 'Cc1cccc(N(C(=O)c2snc(C(N)=O)c2N)C(C(=O)NCC2CCCO2)c2cccs2)c1', 'Cc1cccc(NC(=O)CSC(N)=O)c1C', 'Cc1cccn2c(=O)c3cc(C(=O)NC(C)c4ccccc4)c(=N)n(CCCn4ccnc4)c3nc12', 'Cc1cccn2c(=O)c3cc(C(N)=S)c(=N)n(CCCOC(C)C)c3nc12', 'Cc1nn(-c2ccccc2)c(C)c1/C=N/NC(=O)CSc1nnc(SCc2cccc3ccccc23)s1', 'Cc1oc(-c2ccccc2)nc1CS(=O)CC(=O)N1CCc2ccccc2C1', 'Cc1sc(NC(=O)c2ccccc2)c(C(=O)c2ccccc2)c1C', 'Cc1sc2ncnc(NCC[NH+]3CCOCC3)c2c1C', 'N#CCSc1nc2ccccc2c(=O)n1CCC(=O)NC1CCCCC1', 'Nc1ccn([C@@H]2C(F)=C(CO)[C@@H](O)[C@H]2O)c(=O)n1', 'Nc1nnc(SCCN2C(=O)c3ccccc3C2=O)s1', 'O=C(CS(=O)CC(=O)N(CC(=O)NC1CCCC1)C1CCCCC1)Nc1ccc(F)cc1', 'O=C(CSc1nc2ccccc2c(=O)n1-c1ccccc1F)Nc1ccc2c(c1)CCC2']

# %%
no_gens = []
for k, v in m380_4e_gens.items():
    gt_count = gt_dict[k]["num_confs"]
    gen_count = len(v)
    if gt_count * 2 != gen_count:

        print(gt_count * 2, gen_count)
        print('***')
# print(len(no_gens))
